# %%
from phi.torch import flow
from tqdm import trange
from matplotlib import pyplot as plt

# %%
WORLD_WIDTH = 60
WORLD_HEIGHT = 60

# SPEED_X = 10
# SPEED_Y = 0
# SPEED_X2 = -10
# SPEED_Y2 = 0

# SPEEDS = flow.tensor([SPEED_X, SPEED_Y])

# %%
values = flow.math.random_uniform(flow.spatial(x=60, y=60))
bounds = flow.Box["x,y", 0:60, 0:60]

# %%
velocity = flow.CenteredGrid(
    values,
    0,
    bounds
)
velocity
# Out:
# Grid[(xˢ=60, yˢ=60) 0.505 ± 0.283 (1e-03...1e+00), ext=0]

# %%
flow.vis.plot(velocity)
plt.show()

# %%
velocity.resolution
# Out:
# (xˢ=60, yˢ=60)
